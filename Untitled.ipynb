# %%
def take_second(elem):
    return elem[1]

# 讀取keyword資料
keywordDict = {}
count1 = 0
with open("new_keyword0317.txt","r",encoding="utf-8") as kwh:
    data = kwh.read()
    data_line = data.split("\n")
    kwSet = set()
    for i in range(1, len(data_line)-1):
        # print("data",data_line[i])
        a = eval(data_line[i])

        if a[0].strip().upper() not in keywordDict:
            keywordDict[a[0].strip().upper()] = a[1]
        else:
            keywordDict[a[0].strip().upper()] = keywordDict[a[0].strip().upper()] + a[1]
print(keywordDict)
# Out:
# {'韓國瑜': 11451, '經濟': 6460, '川普': 6178, '民進黨': 5371, '柯文哲': 5092, '蔡英文': 5076, '華航': 4486, '國民黨': 4450, '春節': 3969, '罷工': 3933, '警察': 3490, '北京': 3401, '行政院': 3376, '營收': 3293, '機師': 3096, '香港': 3087, '習近平': 2779, '蘇貞昌': 2711, '北市': 2678, '北韓': 2457, '朱立倫': 2411, '高雄市': 2222, '台中市': 2149, '英國': 2103, '教育部': 2058, '人民幣': 2027, '總統大選': 1976, '吳敦義': 1957, '新台幣': 1943, '酒駕': 1914, '台股': 1908, '美國': 1907, '新竹': 1829, '金正恩': 1831, '王金平': 1791, '華為': 1787, '立委補選': 1762, '5G': 1946, '台灣': 1647, '越南': 1620, '立法院': 1581, '中國': 1611, '台灣燈會': 1571, '紅包': 1544, '印度': 1541, '公投': 1492, '侯友宜': 1465, '毒品': 1440, '貿易戰': 1442, '農委會': 1415, '盧秀燕': 1388, '農民': 1382, '國道': 1368, '連假': 1334, '非洲豬瘟': 1324, '高雄': 1308, '醫師': 1306, '車禍': 1292, '民調': 1269, '謝龍介': 1258, '上海': 1236, '林佳龍': 1228, '蘋果': 1222, '大陸': 1205, '馬英九': 1201, '患者': 1195, '台積電': 1189, '鄭文燦': 1186, '南韓': 1153, '外資': 1142, '中共': 1116, '法國': 1108, '德國': 1103, '外交部': 1080, '檢察官': 1057, '基隆': 1057, '川金會': 1055, '經濟部': 1042, '建築': 1033, '台大': 1027, '俄羅斯': 1002, '金門': 994, '澳洲': 993, '勞動部': 990, '機場': 990, '新加坡': 988, '手機': 986, '委內瑞拉': 979, '台商': 976, '公司': 971, '鴻海': 960, '計程車': 960, '台東': 944, '一國兩制': 944, 'NBA': 945, '九二共識': 936, '歐盟': 934, '民主黨': 926, '警方': 914, '電影': 911, '賴清德': 908, '加拿大': 906, '殺人': 902, '高鐵': 895, '中美貿易戰': 894, '保險': 894, '泰國': 892, '燈會': 891, '氣象局': 869, '學測': 869, '性侵': 868, '脫歐': 861, '情人節': 861, '兩岸關係': 855, '新北': 852, '郭國文': 851, '美股': 828, '馬來西亞': 825, '半導體': 813, '紐約': 809, '核四': 803, '鄭世維': 800, '台彩': 796, '金管會': 793, '菲律賓': 778, '三星': 770, '元宵節': 766, '薪資': 763, '國防部': 753, '市場': 747, '白宮': 745, '桃園機場': 745, '疫情': 741, '觀點投書': 741, '捷運': 736, '日本': 736, '卓榮泰': 733, '結婚': 732, '手術': 715, '義大利': 707, '華航勞資爭議': 704, 'IPHONE': 736, '中職': 700, '孟晚舟': 706, '廣告': 684, '台鐵': 679, '海巡署': 677, '咖啡': 673, '波音': 665, '國
from datetime import datetime
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
import numpy as np
import sys
import cb104_addr

# "CT" "apple" "storm" "udn"
paper_name = "CT"

mongodb_db_host = cb104_addr.local_mongodb_host
mongodb_db_name = "keyword_filter"
mongodb_collection = paper_name + "_news"

mariadb_host = cb104_addr.local_mariadb_host
mariadb_user = cb104_addr.local_mariadb_user
mariadb_pw = cb104_addr.local_mariadb_pw
mariadb_db_name = "news_db"
mariadb_tablename = paper_name + "_news"

conn_md = MongoClient(mongodb_db_host)
mdb = conn_md[mongodb_db_name]
mcollection = mdb[mongodb_collection]

conn = MySQLdb.connect(host=mariadb_host, user=mariadb_user, passwd=mariadb_pw, db=mariadb_db_name, charset="utf8")
cursor = conn.cursor()

sql_command = "select create_time,tag,title_keyword_1,title_keyword_2,title_keyword_3,keyword_1,keyword_2,keyword_3," \
              "keyword_4,keyword_5,views_48 from " + mariadb_tablename + \
              " where views_48 is not null and create_time > '2019-02-07'"
cursor.execute(sql_command)
sql_data = cursor.fetchall()
cursor.close()
conn.close()

print(len(sql_data))

delList = []
for keyword in keywordDict:
    if keywordDict[keyword] < 100:
        delList.append(keyword)

for keyword in delList:
    del keywordDict[keyword]

for i in range(10,21):
    if str(i) in keywordDict:
        del keywordDict[str(i)]
title = ["k1_24", "k1_72", "k1_168", "k1_trend",
         "k2_24", "k2_72", "k2_168", "k2_trend",
         "k3_24", "k3_72", "k3_168", "k3_trend", "48hr_views","tag"]
df_news = pd.DataFrame(columns=title)


print("斷點1")
count_data = 0
for sqlDataOneRow in sql_data:
    newsCreateTime = sqlDataOneRow[0]
    # print(newsCreateTime)
    titleCount = 0
    dfData = {}
    keywordData = set()
    # 這邊要判斷有沒有進重要字
    for keywordPos in range(2, 10):
        if sqlDataOneRow[keywordPos] is not None:
            keywordData.add(sqlDataOneRow[keywordPos].strip().upper())

    sqlKeywordList = []
    for keyword in keywordData:
        if keyword in keywordDict:
            sqlKeywordList.append([keyword, keywordDict[keyword]])

    if len(sqlKeywordList) >= 3:
        count1 = count1 + 1
        sqlKeywordList.sort(key=take_second, reverse=True)
        # print(sqlKeywordList)
    else:
        continue
    count_data = count_data + 1
    if count_data % 100 == 0:
        print("已處理資料:",count_data)
    keyName = ["k1", "k2", "k3"]
    try:
        for keywordPos in range(3):
            # views = [[0],[0],[0],[0],[0],[0],[0]]
            views = [0,0,0,0,0,0,0]
            m_data = mcollection.find({"keyword": sqlKeywordList[keywordPos][0]})[0]
            # print(m_data)
            for viewsCreateTimeStr in m_data["views"]:
                viewsCreateTime = datetime.strptime(viewsCreateTimeStr, "%Y-%m-%d %H:%M")
                dayDiff = (newsCreateTime - viewsCreateTime).total_seconds() // 86400
                dayDiff = int(dayDiff)
                if 0 <= dayDiff < 7:
                    # print(viewsCreateTime, newsCreateTime, dayDiff, m_data["views"][viewsCreateTimeStr])
                    views[dayDiff] = views[dayDiff] + int(m_data["views"][viewsCreateTimeStr])
                dfData[keyName[keywordPos]+"_24"] = views[0]
                dfData[keyName[keywordPos]+"_72"] = views[1] + views[2]
                dfData[keyName[keywordPos]+"_168"] = views[3] + views[4] + views[5] + views[6]
                # 計算斜率
                # model = LinearRegression(fit_intercept=True)
                lm = LinearRegression()
                # print(views)
                lm.fit(np.array([[0], [-1], [-2], [-3], [-4], [-5], [-6]]), np.array(views))
                # print(lm.intercept_)
                # print(lm.coef_)
                dfData[keyName[keywordPos] + "_trend"] = lm.coef_
        dfData["48hr_views"] = sqlDataOneRow[-1]
        dfData["tag"] = sqlDataOneRow[1]
        df_news = df_news.append(dfData, ignore_index=True)
    except Exception as e:
        print(sqlKeywordList)
        print(e)
# Out:
# 2756
# 斷點1
# 已處理資料: 100
# 已處理資料: 200
# 已處理資料: 300
# 已處理資料: 400
# 已處理資料: 500
# 已處理資料: 600
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-6a194c795979> in <module>
#     104                 lm = LinearRegression()
#     105                 # print(views)
# --> 106                 lm.fit(np.array([[0], [-1], [-2], [-3], [-4], [-5], [-6]]), np.array(views))
#     107                 # print(lm.intercept_)
#     108                 # print(lm.coef_)
#
# E:\Pycharm\newsAnalysis\venv\lib\site-packages\sklearn\linear_model\base.py in fit(self, X, y, sample_weight)
#     483         else:
#     484             self.coef_, self._residues, self.rank_, self.singular_ = \
# --> 485                 linalg.lstsq(X, y)
#     486             self.coef_ = self.coef_.T
#     487
#
# E:\Pycharm\newsAnalysis\venv\lib\site-packages\scipy\linalg\basic.py in lstsq(a, b, cond, overwrite_a, overwrite_b, check_finite, lapack_driver)
#    1232
#    1233                 x, s, rank, info = lapack_func(a1, b1, lwork,
# -> 1234                                                iwork, cond, False, False)
#    1235             else:  # complex data
#    1236                 lwork, rwork, iwork = _compute_lwork(lapack_lwork, m, n,
#
# KeyboardInterrupt:

# %%
df_news.to_pickle("./data/df_news_3keyword_com_" + paper_name + ".pkl")

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
plt.figure(figsize=(28,20))
plt.title("heatmap",y = 1.05,size = 30)
sns.heatmap(df_news.astype(float).corr(),cmap = "BrBG",linewidths=0.1,square=True, linecolor="white",annot=True)

# %%
a = list(df_news["48hr_views"])
print(max(a),min(a))
# Out:
# 1555814 230

# %%
import math
df_log = df_news
kw_title = list(df_log.columns)
kw_title = [e for e in kw_title if e not in ["k1_trend","k2_trend","k3_trend","tag"]]
kw_title = ["k1_24", "k1_72", "k1_168",
         "k2_24", "k2_72", "k2_168",
         "k3_24", "k3_72", "k3_168", "48hr_views"]
df_log[kw_title] = df_log[kw_title].applymap(lambda x: math.log10(x+1))

# %%
df_tag = df_news[df_news["tag"] == "生活"]
df_tag
# Out:
#         k1_24    k1_48   k1_168               k1_trend   k2_24    k2_48  \
# 1560     1276    21899    38587   [-178.7500000000001]   10775    39735
# 1561    18531    38903   156349  [-3969.6785714285716]  421134  1075711
# 1562     3182    25422    59762   [1417.0714285714287]   14620     9821
# 1563   215497   230761   561070    [7176.607142857139]   15499    38459
# 1564    45313   158794   129541    [12059.92857142857]   15499    38459
# 1565    27854   165456    48082    [7972.357142857141]     627    19840
# 1566   250809   138757   241283   [23549.428571428565]    3665    17113
# 1567     3665    17113   238996  [-19706.535714285717]  216689   236699
# 1568     2172     3190   149194   [-10299.10714285714]   42239   158078
# 1569    25983    19785   511353   [-9251.678571428569]   25831        0
# 1570    24534   279129    46585    [15613.10714285714]  186788   281048
# 1571   186788   281048   564973    [6056.535714285713]     460     2910
# 1572     2250     3487   148967  [-10573.178571428569]  186788   281048
# 1564    [9422.857142857141]       4089  生活
# 1565  [-12193.642857142855]      27875  生活
# 1566   [1450.4285714285716]        828  生活
# 1567    [79953.21428571426]       6941  生活
# 1568  [-1279.3571428571424]       1708  生活
# 1569   [-5233.607142857142]      14178  生活
# 1570   [-889.0714285714276]       7363  生活
# 1571   [428.17857142857133]      77965  生活
# 1572    [79350.42857142855]        713  生活
# 1573   [-36378.67857142856]      84983  生活
# 1574                 [-0.0]       3233  生活
# 1575  [-3489.2142857142853]       5153  生活
# 1576    [71297.39285714284]       6373  生活
# 1577    [3606.642857142858]       5313  生活
# 1578  [-3232.2857142857138]      61854  生活
# 1579   [-82.32142857142871]       3619  生活
# 1580  [-1145.5357142857138]      15993  生活
# 1581    [2227.500000000002]       9116  生活
# 1582   [309.64285714285757]       6945  生活
# 1583   [-5803.035714285713]       6838  生活
# 1584   [-33205.99999999999]      30821  生活
# 1585   [-5803.035714285713]       4298  生活
# 1586   [10087.071428571426]     609829  生活
# 1587   [-4769.785714285713]     286793  生活
# 1588              [6195.75]      49549  生活
# 1589    [17015.10714285714]      16307  生活
# ...                     ...        ...  ..
# 2408  [-1391.5714285714284]        816  生活
# 2409   [-926.7142857142853]       4466  生活
# 2410  [-16998.464285714283]     183607  生活
# 2411  [-12477.499999999993]      29981  生活
# 2412    [22127.28571428571]      12315  生活
# 2413   [-4246.214285714286]       6158  生活
# 2414   [3508.1428571428573]       8090  生活
# 2415  [-10246.892857142855]       3945  生活
# 2416  [-1154.3928571428569]       4173  生活
# 2417  [-1874.0714285714284]      44335  生活
# 2418    [8161.392857142856]      18433  生活
# 2419    [56330.49999999999]       3034  生活
# 2420                 [-0.0]       7981  生活
# 2421   [1009.9285714285712]       3191  生活
# 2422    [761.4642857142854]      35524  生活
# 2423                 [-0.0]       1021  生活
# 2424                 [-0.0]       2736  生活
# 2425   [305.03571428571416]       4115  生活
# 2426  [-19283.214285714286]       3216  生活
# 2427                 [-0.0]       1460  生活
# 2428                 [-0.0]       2095  生活
# 2429   [-5318.535714285713]       1934  生活
# 2430    [627.6428571428571]        858  生活
# 2431    [7654.357142857142]       1024  生活
# 2432   [-9890.142857142853]     106450  生活
# 2433  [-10020.321428571428]       8356  生活
# 2434  [-26632.535714285714]       1134  生活
# 2435  [-2345.4999999999995]       2194  生活
# 2436    [5526.571428571427]        810  生活
# 2437   [12616.321428571428]        992  生活
#
# [878 rows x 14 columns]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
plt.figure(figsize=(28,20))
plt.title("heatmap",y = 1.05,size = 30)
sns.heatmap(df_log.drop("tag",axis=1).astype(float).corr(),cmap = "BrBG",linewidths=0.1,square=True, linecolor="white",annot=True)

# %%
def change48VToClass(num):
    if num <= 1000:
        return "一千以下"
    elif num <= 10000:
        return "一萬以下"
    elif num <= 100000:
        return "十萬以下"
    elif num <= 1000000:
        return "百萬以下"
    else:
        return "超過百萬"

print(max(list(df_news["48hr_views"])))
    
df_news_cls = df_news
df_news_cls["class"] = df_news["48hr_views"].apply(change48VToClass)

a = set()
for tmp in list(df_news_cls["class"]):
    a.add(tmp)
print(a)
# Out:
# 6.191957954314471
# {'一千以下'}

# %%
# 這段先別用
from sklearn.model_selection import GridSearchCV


p = {
  "max_depth":range(5, 10),
  "n_estimators":range(20, 30)
}

clf = RandomForestClassifier()

search = GridSearchCV(clf, p, cv=10)

search.fit(x_train, y_train)

print(search.best_params_)

print(search.best_score_)
# Out:
# {'max_depth': 5, 'n_estimators': 20}
# 1.0

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split

x_total = df_news_cls.drop(["class","tag","48hr_views"],axis = 1)
y_total = df_news_cls["class"]

x_train,x_test,y_train,y_test = train_test_split(x_total,y_total,test_size = 0.2)


clf = RandomForestClassifier(n_estimators=26, max_depth= 6)

# np.average(cross_val_score(clf, x_train, y_train, cv=10))
clf = clf.fit(x_train,y_train)

# %%
from sklearn.metrics import accuracy_score
pred = clf.predict(x_test)
print("正確率:",accuracy_score(y_test,pred))
# Out:
# 正確率: 1.0

# %%
# 檢查此欄有幾種數值
a = set()
for tmp in list(y_total):
    a.add(tmp)
print(a)
# Out:
# {'一千以下'}

# %%
df_news
# Out:
#         k1_24 k1_72   k1_168               k1_trend    k2_24 k2_72   k2_168  \
# 0       96077   NaN   232829     [5774.10714285714]   470086   NaN  1633473
# 1       22660   NaN    94832   [2599.7142857142853]        0   NaN        0
# 2       21991   NaN   104812   [-500.5714285714285]   213606   NaN        0
# 3           0   NaN      385   [-38.89285714285713]        0   NaN    65343
# 4       33933   NaN   156987   [10864.678571428569]     2150   NaN      949
# 5      334611   NaN  1580416    [-9906.67857142857]   477729   NaN   285650
# 6       55664   NaN   448914   [-3148.214285714286]   549502   NaN   113578
# 7        5150   NaN   214108  [-18788.464285714283]    11454   NaN   132900
# 8          50   NaN        0   [471.42857142857133]    16747   NaN    62492
# 9       14241   NaN     8326    [4356.107142857142]      109   NaN    19604
# 10      18675   NaN   414542  [-17203.642857142855]    10862   NaN    73046
# 11     563630   NaN  1291070   [3574.0357142857106]   403584   NaN   966004
# 12     563630   NaN  1291070   [3574.0357142857106]     4143   NaN     2271
# 13      62366   NaN   517624   [11383.071428571428]      475   NaN       51
# 14     836408   NaN  1069133     [80277.3214285714]   539795   NaN   666660
# 15        183   NaN    27762   [-590.7142857142856]    22069   NaN    45895
# 16      15764   NaN     5404   [1662.7142857142853]     9861   NaN     8545
# 17     243729   NaN    15076   [28406.357142857134]   197237   NaN   307850
# 18      43684   NaN   600941    [-4666.78571428571]        0   NaN     7590
# 19    1005344   NaN   947929   [132018.67857142858]   628910   NaN   834704
# 20     126724   NaN   575718  [-21933.999999999996]        0   NaN   232241
# 21    1365308   NaN  1325259   [185154.85714285713]   655513   NaN   815509
# 22       2139   NaN        0    [229.1785714285715]    27921   NaN    22259
# 23      35336   NaN  3024125  [-136753.89285714284]    72667   NaN   360802
# 24     875935   NaN  2544409   [137846.14285714284]   764474   NaN  1955151
# 25     979677   NaN  3770690     [51625.5357142857]   812710   NaN  2227802
# 26       8485   NaN    61911     [982.857142857143]    13209   NaN     8080
# 27     997663   NaN  4330724   [-2033.642857142859]   822311   NaN  2453295
# 28     645532   NaN   398272    [77343.57142857142]    61318   NaN   317716
# 29     147000   NaN  1237866    [6741.035714285717]     6372   NaN   702710
# ...       ...   ...      ...                    ...      ...   ...      ...
# 3743      574   NaN    25042   [51.535714285714164]     1663   NaN    17810
