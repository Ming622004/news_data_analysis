# %%
import pandas as pd
df_keyword = pd.read_pickle("appleFilterKeyword.pkl")

# %%
df_keyword["sum"] = df_keyword.sum(axis=1)

# %%
df_keyword.sort_values(by=['sum'],ascending=False)
# Out:
#      keywordName  2019-02-07 00:00  2019-02-07 06:00  2019-02-07 12:00  \
# 2             台灣            470162            529540            566346
# 8             網友            755782            824363            885368
# 1             遊戲            201926            269153            279211
# 106           現金            117511             62326             64570
# 38            女兒            349413            407151            504746
# 172           發現             26580             46654             69831
# 26            中國             71857             59539             80155
# 47            警方             58187             61453             60224
# 212          韓國瑜            108943            155933            177203
# 888           男子             40729             40114             60256
# 208           華航             50818             37044             31798
# 34            兒子            274087            218540            295615
# ...
